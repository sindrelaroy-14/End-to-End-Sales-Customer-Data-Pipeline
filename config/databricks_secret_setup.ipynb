# %%
import urllib.parse

# 1. Enter your credentials here (We will hide these later)
ACCESS_KEY = "##***##"
SECRET_KEY = "##***##**##"
BUCKET_NAME = "s3_bucket"

# 2. Encode the Secret Key (Important: S3 keys often have '/' which breaks URLs)
encoded_secret_key = urllib.parse.quote(SECRET_KEY, safe="")

# 3. Build the connection string
# Format: s3a://ACCESS_KEY:ENCODED_SECRET_KEY@BUCKET_NAME/FOLDER
s3_path = f"s3a://{ACCESS_KEY}:{encoded_secret_key}@{BUCKET_NAME}/landing-zone/"

# 4. Try to list the files
try:
    files = dbutils.fs.ls(s3_path)
    print("✅ Connection Successful!")
    display(files)
except Exception as e:
    print("❌ Connection Failed. Error:")
    print(e)
